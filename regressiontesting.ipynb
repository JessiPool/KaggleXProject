# %% [markdown]
# <a href="https://colab.research.google.com/github/JessiPool/KaggleXProject/blob/regression/regressiontesting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load dataset for regression model - US Rental Listings, 2014-2020

# %%
df = pd.read_csv('/content/drive/MyDrive/Data/KaggleX/pythondata/usrent_merge.csv')

# %%
df
# Out:
#    year_only  percentage  average_CPI  avg_stock_market_closing_value  \
# 0       2014   57.698160   236.715000                     16777.69091
# 1       2015   57.688005   237.001750                     17587.02917
# 2       2016   57.622209   240.005417                     17927.10734
# 3       2017   57.532216   245.121000                     21750.20375
# 4       2018   57.570735   251.099500                     25046.85735
# 5       2019   63.565440   255.651667                     26379.58702
# 6       2020   59.844209   258.850583                     26890.67360
#
#    GDP_by_billion_USD  Per_Capita_USD  Total_in_Billions_USD  \
# 0            17550.68        55123.85                 2527.1
# 1            18206.02        56762.73                 2674.3
# 2            18695.11        57866.74                 2795.6
# 3            19477.34        59907.75                 2903.8
# 4            20533.06        62823.31                 3019.8
# 5            21380.98        65120.39                 3173.1
# 6            21060.47        63528.63                 3367.0
#
#    Out_of_Pocket_in_Billions_USD  Health_Insurance_in_Billions_USD  \
# 0                          340.8                            1948.8
# 1                          353.5                            2076.1
# 2                          365.9                            2170.0
# 3                          372.9                            2258.2
# 4                          386.8                            2348.5
# 5                          403.0                            2468.1
# 6                          392.3                            2492.4
#
#    Private_Health_Insurance_in_Billions_USD  Medicare_in_Billions_USD  \
# 0                                     815.5                     579.3
# 1                                     870.2                     606.2
# 2                                     918.6                     629.0
# 3                                     957.7                     659.1
# 4                                     990.4                     696.7
# 5                                    1029.8                     746.6
# 6                                     995.6                     759.6
#
#    Medicaid_in_Billions_USD  Other_Health_Insurance_Programs_in_Billions_USD  \
# 0                     446.9                                            107.1
# 1                     484.5                                            115.2
# 2                     503.4                                            119.0
# 3                     516.0                                            125.4
# 4                     531.5                                            129.9
# 5                     553.6                                            138.1
# 6                     587.7                                            149.4
#
#    Other_Third_Party_Payers_in_Billions_USD  Total_Federal_Grants_in_Millions  \
# 0                                     237.5                           51430.0
# 1                                     244.6                           50036.0
# 2                                     259.6                           47924.0
# 3                                     272.7                           44790.0
# 4                                     284.5                           45407.0
# 5                                     302.0                           44442.0
# 6                                     482.3                           43165.0
#
#    Total_Federal_Loans_in_Millions  Federal_Work_Study_in_Millions  \
# 0                         117865.0                          1141.0
# 1                         111734.0                          1123.0
# 2                         109213.0                          1122.0
# 3                         106883.0                          1108.0
# 4                         103195.0                          1085.0
# 5                          98481.0                          1208.0
# 6                          95422.0                          1177.0
#
#    Education_Tax_Benefits_in_Millions  \
# 0                             21480.0
# 1                             20630.0
# 2                             19630.0
# 3                             18060.0
# 4                             16110.0
# 5                             14600.0
# 6                             13320.0
#
#    TOTAL_FEDERAL__STATE___INSTITUTIONAL__AND_OTHER_AID_in_Millions  \
# 0                                           276848.0
# 1                                           272117.0
# 2                                           270348.0
# 3                                           266532.0
# 4                                           265610.0
# 5                                           261149.0
# 6                                           258117.0
#
#    NONFEDERAL_LOANS_in_Millions
# 0                       11100.0
# 1                       11600.0
# 2                       12200.0
# 3                       12800.0
# 4                       13200.0
# 5                       14100.0
# 6                       15300.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_56, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_57, *['year_only'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_58, *['percentage'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_59, *['average_CPI'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plot(df, x_colname, y_colname, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(6 * figscale, 6 * figscale))
#   df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha)
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plot(_df_60, *['index', 'year_only'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plot(df, x_colname, y_colname, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(6 * figscale, 6 * figscale))
#   df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha)
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plot(_df_61, *['year_only', 'percentage'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plot(df, x_colname, y_colname, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(6 * figscale, 6 * figscale))
#   df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha)
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plot(_df_62, *['percentage', 'average_CPI'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plot(df, x_colname, y_colname, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(6 * figscale, 6 * figscale))
#   df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha)
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plot(_df_63, *['average_CPI', 'avg_stock_market_closing_value'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_64, *['index', 'percentage', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_65, *['index', 'GDP_by_billion_USD', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_66, *['index', 'Per_Capita_USD', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_67, *['index', 'Out_of_Pocket_in_Billions_USD', None], **{})
# chart
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_68, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_69, *['year_only'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_70, *['percentage'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_71, *['average_CPI'], **{})
# chart

# %%
from sklearn.linear_model import LinearRegression

# %%
df.set_index('year_only')['percentage'] \
.plot(style = '.', title = 'Affordability Percentage by Year')
plt.show()

# %%
# Building the regression model - US Rental Listings, 2014-2020

# %%
X = df.drop(columns = 'percentage')

# %%
y = df['percentage']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
c = lr.intercept_

# %%
c
# Out:
# 289.56714418669213

# %%
m = lr.coef_

# %%
y_pred_train = lr.predict(X_train)

# %%
y_pred_test = lr.predict(X_test)

# %%
y_pred_train
# Out:
# array([57.68800497, 57.53221576, 57.69816019, 63.56544015, 57.57073517])

# %%
import matplotlib.pyplot as plt
plt.scatter(y_train, y_pred_train)
plt.xlabel("Actual Affordability Percentage")
plt.ylabel("Predicted Affordability Percentage")
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train, y_pred_train)
# Out:
# 1.0

# %%
y_pred_test = lr.predict(X_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred_test)
plt.xlabel("Actual Affordability Percentage")
plt.ylabel("Predicted Affordability Percentage")
plt.show()

# %%
r2_score(y_test, y_pred_test)
# Out:
# 0.3898634578309019

# %%
# Attempting Linear Regression on the State-Level Rental Data

# %%
df_st = pd.read_csv('/content/drive/MyDrive/Data/KaggleX/pythondata/staterent_merge.csv')

# %%
df_st
# Out:
#     state  year_only  percentage  average_CPI  avg_stock_market_closing_value  \
# 0      AL       2014   78.950000   236.715000                    16777.690913
# 1      AR       2014  100.000000   236.715000                    16777.690913
# 2      AZ       2014   93.750000   236.715000                    16777.690913
# 3      CA       2014   53.923358   236.715000                    16777.690913
# 4      CO       2014   96.568627   236.715000                    16777.690913
# ..    ...        ...         ...          ...                             ...
# 289    TX       2020   96.563574   258.850583                    26890.673597
# 290    UT       2020  100.000000   258.850583                    26890.673597
# 291    VA       2020   87.800000   258.850583                    26890.673597
# 292    WA       2020   86.785714   258.850583                    26890.673597
# 293    WI       2020   97.500000   258.850583                    26890.673597
#
#     GDP_by_billion_USD Per_Capita_USD  Annual_Percentage_Growth_Change  \
# 0           $17,550.68     $55,123.85                           2.2878
# 1           $17,550.68     $55,123.85                           2.2878
# 2           $17,550.68     $55,123.85                           2.2878
# 3           $17,550.68     $55,123.85                           2.2878
# 4           $17,550.68     $55,123.85                           2.2878
# ..                 ...            ...                              ...
# 289         $21,060.47     $63,528.63                          -2.7678
# 290         $21,060.47     $63,528.63                          -2.7678
# 291         $21,060.47     $63,528.63                          -2.7678
# 292         $21,060.47     $63,528.63                          -2.7678
# 293         $21,060.47     $63,528.63                          -2.7678
#
#     Total_in_Billions_USD Out_of_Pocket_in_Billions_USD  ...  \
# 0               $2,527.10                       $340.80  ...
# 1               $2,527.10                       $340.80  ...
# 2               $2,527.10                       $340.80  ...
# 3               $2,527.10                       $340.80  ...
# 4               $2,527.10                       $340.80  ...
# ..                    ...                           ...  ...
# 289             $3,367.00                       $392.30  ...
# 290             $3,367.00                       $392.30  ...
# 291             $3,367.00                       $392.30  ...
# 292             $3,367.00                       $392.30  ...
# 293             $3,367.00                       $392.30  ...
#
#     Medicare_in_Billions_USD Medicaid_in_Billions_USD  \
# 0                    $579.30                  $446.90
# 1                    $579.30                  $446.90
# 2                    $579.30                  $446.90
# 3                    $579.30                  $446.90
# 4                    $579.30                  $446.90
# ..                       ...                      ...
# 289                  $759.60                  $587.70
# 290                  $759.60                  $587.70
# 291                  $759.60                  $587.70
# 292                  $759.60                  $587.70
# 293                  $759.60                  $587.70
#
#     Other_Health_Insurance_Programs_in_Billions_USD  \
# 0                                           $107.10
# 1                                           $107.10
# 2                                           $107.10
# 3                                           $107.10
# 4                                           $107.10
# ..                                              ...
# 289                                         $149.40
# 290                                         $149.40
# 291                                         $149.40
# 292                                         $149.40
# 293                                         $149.40
#
#     Other_Third_Party_Payers_in_Billions_USD Total_Federal_Grants_in_Millions  \
# 0                                    $237.50                       $51,430.00
# 1                                    $237.50                       $51,430.00
# 2                                    $237.50                       $51,430.00
# 3                                    $237.50                       $51,430.00
# 4                                    $237.50                       $51,430.00
# ..                                       ...                              ...
# 289                                  $482.30                       $43,165.00
# 290                                  $482.30                       $43,165.00
# 291                                  $482.30                       $43,165.00
# 292                                  $482.30                       $43,165.00
# 293                                  $482.30                       $43,165.00
#
#     Total_Federal_Loans_in_Millions Federal_Work_Study_in_Millions  \
# 0                       $117,865.00                      $1,141.00
# 1                       $117,865.00                      $1,141.00
# 2                       $117,865.00                      $1,141.00
# 3                       $117,865.00                      $1,141.00
# 4                       $117,865.00                      $1,141.00
# ..                              ...                            ...
# 289                      $95,422.00                      $1,177.00
# 290                      $95,422.00                      $1,177.00
# 291                      $95,422.00                      $1,177.00
# 292                      $95,422.00                      $1,177.00
# 293                      $95,422.00                      $1,177.00
#
#     Education_Tax_Benefits_in_Millions  \
# 0                           $21,480.00
# 1                           $21,480.00
# 2                           $21,480.00
# 3                           $21,480.00
# 4                           $21,480.00
# ..                                 ...
# 289                         $13,320.00
# 290                         $13,320.00
# 291                         $13,320.00
# 292                         $13,320.00
# 293                         $13,320.00
#
#     TOTAL_FEDERAL__STATE___INSTITUTIONAL__AND_OTHER_AID_in_Millions  \
# 0                                          $276,848.00
# 1                                          $276,848.00
# 2                                          $276,848.00
# 3                                          $276,848.00
# 4                                          $276,848.00
# ..                                                 ...
# 289                                        $258,117.00
# 290                                        $258,117.00
# 291                                        $258,117.00
# 292                                        $258,117.00
# 293                                        $258,117.00
#
#     NONFEDERAL_LOANS_in_Millions
# 0                     $11,100.00
# 1                     $11,100.00
# 2                     $11,100.00
# 3                     $11,100.00
# 4                     $11,100.00
# ..                           ...
# 289                   $15,300.00
# 290                   $15,300.00
# 291                   $15,300.00
# 292                   $15,300.00
# 293                   $15,300.00
#
# [294 rows x 22 columns]

# %%
df_st['state'] = df_st['state'].astype('category')
df_st['state'] = df_st['state'].cat.codes

# %%
df_st.head()
# Out:
#    state  year_only  percentage  average_CPI  avg_stock_market_closing_value  \
# 0      0       2014   78.950000      236.715                    16777.690913
# 1      1       2014  100.000000      236.715                    16777.690913
# 2      2       2014   93.750000      236.715                    16777.690913
# 3      3       2014   53.923358      236.715                    16777.690913
# 4      4       2014   96.568627      236.715                    16777.690913
#
#   GDP_by_billion_USD Per_Capita_USD  Annual_Percentage_Growth_Change  \
# 0         $17,550.68     $55,123.85                           2.2878
# 1         $17,550.68     $55,123.85                           2.2878
# 2         $17,550.68     $55,123.85                           2.2878
# 3         $17,550.68     $55,123.85                           2.2878
# 4         $17,550.68     $55,123.85                           2.2878
#
#   Total_in_Billions_USD Out_of_Pocket_in_Billions_USD  ...  \
# 0             $2,527.10                       $340.80  ...
# 1             $2,527.10                       $340.80  ...
# 2             $2,527.10                       $340.80  ...
# 3             $2,527.10                       $340.80  ...
# 4             $2,527.10                       $340.80  ...
#
#   Medicare_in_Billions_USD Medicaid_in_Billions_USD  \
# 0                  $579.30                  $446.90
# 1                  $579.30                  $446.90
# 2                  $579.30                  $446.90
# 3                  $579.30                  $446.90
# 4                  $579.30                  $446.90
#
#   Other_Health_Insurance_Programs_in_Billions_USD  \
# 0                                         $107.10
# 1                                         $107.10
# 2                                         $107.10
# 3                                         $107.10
# 4                                         $107.10
#
#   Other_Third_Party_Payers_in_Billions_USD Total_Federal_Grants_in_Millions  \
# 0                                  $237.50                       $51,430.00
# 1                                  $237.50                       $51,430.00
# 2                                  $237.50                       $51,430.00
# 3                                  $237.50                       $51,430.00
# 4                                  $237.50                       $51,430.00
#
#   Total_Federal_Loans_in_Millions Federal_Work_Study_in_Millions  \
# 0                     $117,865.00                      $1,141.00
# 1                     $117,865.00                      $1,141.00
# 2                     $117,865.00                      $1,141.00
# 3                     $117,865.00                      $1,141.00
# 4                     $117,865.00                      $1,141.00
#
#   Education_Tax_Benefits_in_Millions  \
# 0                         $21,480.00
# 1                         $21,480.00
# 2                         $21,480.00
# 3                         $21,480.00
# 4                         $21,480.00
#
#   TOTAL_FEDERAL__STATE___INSTITUTIONAL__AND_OTHER_AID_in_Millions  \
# 0                                        $276,848.00
# 1                                        $276,848.00
# 2                                        $276,848.00
# 3                                        $276,848.00
# 4                                        $276,848.00
#
#   NONFEDERAL_LOANS_in_Millions
# 0                   $11,100.00
# 1                   $11,100.00
# 2                   $11,100.00
# 3                   $11,100.00
# 4                   $11,100.00
#
# [5 rows x 22 columns]
